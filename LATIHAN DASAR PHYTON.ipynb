# %%
nama_saya = "hadiyanto"
pekerjaan = "konsultan"
umur = 30

print("nama saya",nama_saya, "pekerjaan sebagai",pekerjaan, "umurku",umur, "tahun")
# Out:
# nama saya hadiyanto pekerjaan sebagai konsultan umurku 30 tahun

# %%
a = 6
b = 4

print("a + b =",a+b)
print("a - b =",a-2)
print("a x b =",a*b)
print("a : b =",a/b)
print("a pangkat b =",a**b)
print("a sisa bagi b =",a%b, "(6 akar 4 = 1 modulo 2)")
print("a floor b =",a//b, "(6 dibagi 2 = 1.5 (dibulatkan kebawah = 1))")
# Out:
# a + b = 10
# a - b = 4
# a x b = 24
# a : b = 1.5
# a pangkat b = 1296
# a sisa bagi b = 2 (6 akar 4 = 1 modulo 2)
# a floor b = 1 (6 dibagi 2 = 1.5 (dibulatkan kebawah = 1))

# %%
(9+8)*3+2*(1+1)
# Out:
# 55

# %%
angka_2 = "5"
angka_1 = 10
angka_2 = int(angka_2)

print(angka_1 + angka_2)
# Out:
# 15

# %%
nama_depan = "Much"
nama_belakang = "hadiyanto"

print(nama_depan, nama_belakang)
# Out:
# Much hadiyanto

# %%
nama_depan = "Much"
nama_belakang = "hadiyanto"

nama_depan + " " + nama_belakang
# Out:
# 'Much hadiyanto'

# %%
nama = "hadiyanto "

nama * 4
# Out:
# 'hadiyanto hadiyanto hadiyanto hadiyanto '

# %%
angka_1 = True
angka_2 = False

print(type(angka_1))
print(type(angka_2))
angka_1 + angka_1
# Out:
# <class 'bool'>
# <class 'bool'>
# 2

# %%
var_input = input("Nama : ")
var_input = input("Tempat/ Tgl. lahir : ")
var_input = input("Alamat : ")
# Out:
# Nama : Hadiyanto
# Tempat/ Tgl. lahir : Surakarta, 10-10-2001
# Alamat : Kratonan Surakarta
